# %% [markdown]
# pip install xgboost

# %%
#data preprocessing
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from IPython.display import display
# %matplotlib inline

# %%
game = pd.read_csv('game.csv')
game
# Out:
#           game_id    season type   date_time         date_time_GMT  \
# 0      2011030221  20112012    P  2012-04-29  2012-04-29T19:00:00Z
# 1      2011030222  20112012    P  2012-05-01  2012-05-01T23:30:00Z
# 2      2011030223  20112012    P  2012-05-03  2012-05-03T23:30:00Z
# 3      2011030224  20112012    P  2012-05-06  2012-05-06T23:30:00Z
# 4      2011030225  20112012    P  2012-05-08  2012-05-08T23:30:00Z
# 5      2011030411  20112012    P  2012-05-31  2012-05-31T00:00:00Z
# 6      2011030412  20112012    P  2012-06-03  2012-06-03T00:00:00Z
# 7      2011030413  20112012    P  2012-06-05  2012-06-05T00:00:00Z
# 8      2011030414  20112012    P  2012-06-07  2012-06-07T00:00:00Z
# 9      2011030415  20112012    P  2012-06-10  2012-06-10T00:00:00Z
# 10     2011030416  20112012    P  2012-06-12  2012-06-12T00:00:00Z
# 11     2010030311  20102011    P  2011-05-15  2011-05-15T00:00:00Z
# 12     2010030312  20102011    P  2011-05-18  2011-05-18T00:00:00Z
# ...

# %%
game_goalie = pd.read_csv("game_goalie_stats.csv ")

# %%
game_teams_stats = pd.read_csv("game_teams_stats.csv ")

# %%
game_goalie
# Out:
#           game_id  player_id  team_id  timeOnIce  assists  goals  pim  shots  \
# 0      2011030221    8455710        1       3876        0      0    0     36
# 1      2011030221    8468524        4       3876        0      0    0     26
# 2      2011030222    8455710        1       3599        0      0    0     20
# 3      2011030222    8468524        4       3559        0      0    0     34
# 4      2011030223    8468524        4       4623        0      0    0     31
# ...           ...        ...      ...        ...      ...    ...  ...    ...
# 24641  2018030415    8471695        6       3522        0      0    0     21
# 24642  2018030416    8471695        6       3600        0      0    0     29
# 24643  2018030416    8476412       19       3487        0      0    0     31
# 24644  2018030417    8476412       19       3600        0      0    0     33
# 24645  2018030417    8471695        6       3394        0      0    0     20
#
# ...

# %%
game_teams_stats
# Out:
#           game_id  team_id   HoA    won settled_in        head_coach  goals  \
# 0      2011030221        1  away  False         OT      Peter DeBoer      3
# 1      2011030221        4  home   True         OT  Peter Laviolette      4
# 2      2011030222        1  away   True        REG      Peter DeBoer      4
# 3      2011030222        4  home  False        REG  Peter Laviolette      1
# 4      2011030223        4  away  False         OT  Peter Laviolette      3
# 5      2011030223        1  home   True         OT      Peter DeBoer      4
# 6      2011030224        4  away  False        REG  Peter Laviolette      2
# 7      2011030224        1  home   True        REG      Peter DeBoer      4
# 8      2011030225        1  away   True        REG      Peter DeBoer      3
# 9      2011030225        4  home  False        REG  Peter Laviolette      1
# 10     2011030411       26  away   True         OT     Darryl Sutter      2
# ...

# %%
df = game_teams_stats.merge(game_goalie, on=['team_id','game_id'])

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#           game_id  team_id   HoA    won settled_in        head_coach  goals_x  \
# 0      2011030221        1  away  False         OT      Peter DeBoer        3
# 1      2011030221        4  home   True         OT  Peter Laviolette        4
# 2      2011030222        1  away   True        REG      Peter DeBoer        4
# 3      2011030222        4  home  False        REG  Peter Laviolette        1
# 4      2011030223        4  away  False         OT  Peter Laviolette        3
# 5      2011030223        1  home   True         OT      Peter DeBoer        4
# 6      2011030224        4  away  False        REG  Peter Laviolette        2
# 7      2011030224        1  home   True        REG      Peter DeBoer        4
# 8      2011030225        1  away   True        REG      Peter DeBoer        3
# 9      2011030225        4  home  False        REG  Peter Laviolette        1
# 10     2011030411       26  away   True         OT     Darryl Sutter        2
# ...

# %%
teamsDF = df.drop(['HoA','won','settled_in','head_coach','goals_y','assists','pim_y','decision','player_id'],axis=1)
teamsDF
# Out:
#           game_id  team_id  goals_x  shots_x  hits  pim_x  \
# 0      2011030221        1        3       26    31     12
# 1      2011030221        4        4       36    27      6
# 2      2011030222        1        4       35    32     12
# 3      2011030222        4        1       20    24     32
# 4      2011030223        4        3       28    28      4
# 5      2011030223        1        4       31    30     10
# 6      2011030224        4        2       22    23     10
# 7      2011030224        1        4       43    19      4
# 8      2011030225        1        3       30    26      2
# 9      2011030225        4        1       28    38      8
# 10     2011030411       26        2       25    35      4
# 11     2011030411        1        1       17    44      2
# 12     2011030412       26        2       32    32      8
# 13     2011030412        1        1       33    35      4
# 14     2011030413        1        0       22    32      6
# ...

# %%
df2 = teamsDF.groupby(['game_id','team_id']).mean()
df2.to_csv('test.csv')
